# %% [markdown]
# ## Create a fresh environment

# %%
# !pip install -U langchain langchain-community langchain-text-splitters
# !pip install -U langchain-ollama langchain-huggingface
# !pip install -U langchain-chroma chromadb
# !pip install -U pypdf
# Out:
# Requirement already satisfied: langchain in c:\users\ankit\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: langchain-community in c:\users\ankit\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-text-splitters in c:\users\ankit\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in c:\users\ankit\anaconda3\lib\site-packages (from langchain) (1.2.6)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\ankit\anaconda3\lib\site-packages (from langchain) (1.0.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ankit\anaconda3\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.6.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (24.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (8.2.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ankit\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (2.1)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.1)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.27.0)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.2.0)
# Requirement already satisfied: certifi in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: idna in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.7)
# Requirement already satisfied: sniffio in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ankit\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\ankit\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ankit\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ankit\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ankit\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: langchain-ollama in c:\users\ankit\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: langchain-huggingface in c:\users\ankit\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-ollama) (1.2.6)
# Requirement already satisfied: ollama<1.0.0,>=0.6.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-ollama) (0.6.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.6.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (8.2.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ankit\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.27.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.23.0)
# Requirement already satisfied: anyio in c:\users\ankit\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (4.2.0)
# Requirement already satisfied: certifi in c:\users\ankit\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\ankit\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.0.2)
# Requirement already satisfied: idna in c:\users\ankit\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.7)
# Requirement already satisfied: sniffio in c:\users\ankit\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ankit\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.4.2)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.33.4 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-huggingface) (0.35.1)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-huggingface) (0.22.1)
# Requirement already satisfied: filelock in c:\users\ankit\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2024.6.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\ankit\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ankit\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ankit\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.2.3)
# Requirement already satisfied: colorama in c:\users\ankit\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: langchain-chroma in c:\users\ankit\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: chromadb in c:\users\ankit\anaconda3\lib\site-packages (1.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-chroma) (1.2.6)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-chroma) (1.26.4)
# Requirement already satisfied: build>=1.0.3 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (2.12.5)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\ankit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.40.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (3.11.5)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.6.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (24.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ankit\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.23.0)
# Requirement already satisfied: anyio in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: certifi in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: sniffio in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ankit\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.5 in c:\users\ankit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\ankit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\ankit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ankit\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ankit\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.2.3)
# Requirement already satisfied: pyproject_hooks in c:\users\ankit\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\ankit\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.10.6)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\ankit\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.45.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\ankit\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\ankit\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\ankit\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ankit\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ankit\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\ankit\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Requirement already satisfied: coloredlogs in c:\users\ankit\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\ankit\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\ankit\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.2)
# Requirement already satisfied: sympy in c:\users\ankit\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\ankit\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\ankit\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\ankit\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in c:\users\ankit\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in c:\users\ankit\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\ankit\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ankit\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ankit\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\ankit\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.35.1)
# Requirement already satisfied: filelock in c:\users\ankit\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\ankit\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\ankit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\ankit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\ankit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\ankit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\ankit\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\ankit\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pypdf in c:\users\ankit\anaconda3\lib\site-packages (6.6.0)

# %% [markdown]
# ## Step 1 — Install & run an open-source LLM (Ollama)
# Instead of relying on closed APIs, the system uses Ollama for local LLM inference, HuggingFace for embeddings, and Chroma / FAISS for vector storage.
# The use case is document-grounded question answering over the Scrum Guide PDF, ensuring answers are evidence-based and not hallucinated

# %%
# !ollama --version
# !ollama run llama3 "Say hello in one line"
# Out:
# ollama version is 0.14.1

# %% [markdown]
# ## Sanity check
# Ollama is running
# LangChain can talk to the model
# The LLM can successfully generate text

# %%
import requests
r = requests.get("http://localhost:11434")
print("Status:", r.status_code)
print(r.text[:200])
# Out:
# Status: 200
# Ollama is running

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3", temperature=0)
llm.invoke("Say hello in one line")
# Out:
# AIMessage(content='"Hello there!"', additional_kwargs={}, response_metadata={'model': 'llama3', 'created_at': '2026-01-16T09:21:32.1665224Z', 'done': True, 'done_reason': 'stop', 'total_duration': 13857604900, 'load_duration': 10848544600, 'prompt_eval_count': 15, 'prompt_eval_duration': 2003725300, 'eval_count': 5, 'eval_duration': 962335800, 'logprobs': None, 'model_name': 'llama3', 'model_provider': 'ollama'}, id='lc_run--019bc61b-efd7-7571-bb76-fc4093efad39-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 5, 'total_tokens': 20})

# %% [markdown]
# ## Document Ingestion (PDF Loading & Validation)
# Ingest the Scrum Guide PDF as structured documents,
# Each page is converted into a LangChain Document object,
# Enabling chunking, embedding, and retrieval during QA.
# ###### PyPDFLoader turns the Scrum Guide into structured Document objects
# the document was loaded page-by-page into 14 structured Document objects.
# At this stage, the content is too large for direct LLM input, which makes chunking necessary.

# %%
from langchain_community.document_loaders import PyPDFLoader
import os

pdf_path = r"C:\Users\ankit\OneDrive\Desktop\Data Science\2020-Scrum-Guide-US.pdf"

if os.path.exists(pdf_path):
    loader = PyPDFLoader(pdf_path)
    docs = loader.load()
    print(f"Pages loaded: {len(docs)}")
    print(docs[0].page_content[:400])
else:
    print(f"Error: The file '{pdf_path}' does not exist.")
# Out:
# WARNING:tensorflow:From C:\Users\ankit\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Pages loaded: 14
# Ken Schwaber & Jeff Sutherland
#
#
#
#
#
#
#
#
#
#
# The Scrum Guide
#
# The Definitive Guide to Scrum: The Rules of the Game
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# November 2020

# %% [markdown]
# ## Split into chunks
# a Recursive Character Text Splitter (to maintain semantic context) with a chunk size of 800 characters and a 120-character overlap.
# Overlap ensures continuity of context across chunk boundaries.
# This resulted in 51 chunks, which balances retrieval precision with sufficient semantic context.
#
# ## Text Chunking (Preparing Documents for Retrieval)
# This step breaks the loaded Scrum Guide text into smaller, overlapping pieces so the system can:
# Create embeddings
# Store them efficiently
# Retrieve only the most relevant parts for each question
#
# 1️⃣ Recursive Character Text Splitter
#
# This is a text-splitting method that:
#
# Tries to split text at natural boundaries first (paragraphs, sentences)
#
# Only splits by characters if it can’t find a clean boundary
#
# 👉 Purpose: keep meaning intact, not break sentences awkwardly.
#
# 2️⃣ “To maintain semantic context”
#
# This explains why it’s used:
#
# Each chunk contains complete, meaningful ideas
#
# Related sentences stay together
#
# Embeddings represent coherent concepts instead of fragments
#
# 👉 Result: better retrieval + fewer hallucinations in RAG.
#
# 3️⃣ Chunk size = 800 characters
#
# This means:
#
# Each chunk can be up to 800 characters long
#
# Roughly:
#
# ~120–150 words
#
# ~6–8 sentences (varies)
#
# 👉 Why 800?
#
# Big enough to hold context
#
# Small enough to fit embedding & LLM context windows efficiently
#
# 4️⃣ Overlap = 120 characters
#
# This means:
#
# The last 120 characters of one chunk are repeated in the next chunk
#
# Example:
#
# Chunk 1: [.........ABCDE]
# Chunk 2:        [ABCDE.........]
#
#
# 👉 Why overlap?
#
# Prevents losing context at chunk boundaries
#
# Ensures important sentences aren’t split across chunks

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter =RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=120
)
splits=text_splitter.split_documents(docs)
print("Chunks Created:",len(splits))
print(splits[0].page_content[:400])
# Out:
# Chunks Created: 51
# Ken Schwaber & Jeff Sutherland
#
#
#
#
#
#
#
#
#
#
# The Scrum Guide
#
# The Definitive Guide to Scrum: The Rules of the Game
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# November 2020

# %%
pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\ankit\anaconda3\lib\site-packages (5.2.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\ankit\anaconda3\lib\site-packages (from sentence-transformers) (4.56.2)
# Requirement already satisfied: tqdm in c:\users\ankit\anaconda3\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\ankit\anaconda3\lib\site-packages (from sentence-transformers) (2.8.0+cpu)
# Requirement already satisfied: scikit-learn in c:\users\ankit\anaconda3\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\ankit\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\ankit\anaconda3\lib\site-packages (from sentence-transformers) (0.35.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\users\ankit\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\ankit\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ankit\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ankit\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ankit\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\ankit\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\ankit\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\ankit\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ankit\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx in c:\users\ankit\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\ankit\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\ankit\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\ankit\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ankit\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ankit\anaconda3\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ankit\anaconda3\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ankit\anaconda3\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ankit\anaconda3\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tf-keras
# Out:
# Requirement already satisfied: tf-keras in c:\users\ankit\anaconda3\lib\site-packages (2.20.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: tensorflow<2.21,>=2.20 in c:\users\ankit\anaconda3\lib\site-packages (from tf-keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (24.1)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (6.33.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.12.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ankit\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ankit\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ankit\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ankit\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ankit\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.4.1)
# Requirement already satisfied: pillow in c:\users\ankit\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (10.4.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ankit\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ankit\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.45.1)
# Requirement already satisfied: rich in c:\users\ankit\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\ankit\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\ankit\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.18.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ankit\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ankit\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ankit\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)

# %%
# !pip install tf-keras
# Out:
# Requirement already satisfied: tf-keras in c:\users\ankit\anaconda3\lib\site-packages (2.20.1)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in c:\users\ankit\anaconda3\lib\site-packages (from tf-keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (24.1)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (6.33.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.12.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\ankit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ankit\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ankit\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ankit\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ankit\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ankit\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.4.1)
# Requirement already satisfied: pillow in c:\users\ankit\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (10.4.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ankit\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ankit\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ankit\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.45.1)
# Requirement already satisfied: rich in c:\users\ankit\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\ankit\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\ankit\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.18.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ankit\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ankit\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ankit\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)

# %% [markdown]
# ## Create embeddings (open-source)
# Embeddings convert text into numbers so the computer can compare meaning, not just words

# %%
"This is a Scrum Guide"
→ [0.012, -0.443, 0.981, ..., 0.217]   ← 768-dim vector

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-mpnet-base-v2"
)

print("Embeddings ready ✅")
# Out:
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 3a44a562-4295-47b3-b1f2-93b127943892)')' thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/./config_sentence_transformers.json
# Retrying in 1s [Retry 1/5].
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: ad221f06-9d6e-4120-a17c-66a501717672)')' thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/./config_sentence_transformers.json
# Retrying in 2s [Retry 2/5].
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: df8c9486-f953-4d50-8b8c-d52a4ec25892)')' thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/./README.md
# Retrying in 1s [Retry 1/5].
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: b1bb0c58-9d3a-4d80-989d-fadd2a2c712c)')' thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/adapter_config.json
# Retrying in 1s [Retry 1/5].
# Embeddings ready ✅

# %%
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\ankit\anaconda3\lib\site-packages (7.8.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\ankit\anaconda3\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\ankit\anaconda3\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\ankit\anaconda3\lib\site-packages (from ipywidgets) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from ipywidgets) (8.27.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\ankit\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets) (7.2.2)
# Requirement already satisfied: decorator in c:\users\ankit\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ankit\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ankit\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ankit\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\ankit\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\ankit\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\ankit\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\ankit\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\ankit\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\ankit\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.4.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (7.4.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (24.1)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\ankit\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.2.0)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (80.9.0)
# Requirement already satisfied: babel>=2.10 in c:\users\ankit\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\ankit\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\ankit\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\ankit\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.32.5)
# Requirement already satisfied: idna>=2.8 in c:\users\ankit\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ankit\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ankit\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\ankit\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2024.1)
# Requirement already satisfied: certifi in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ankit\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ankit\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.6.7)
# Requirement already satisfied: nest-asyncio in c:\users\ankit\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.6.0)
# Requirement already satisfied: psutil in c:\users\ankit\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ankit\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\ankit\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.1)
# Requirement already satisfied: uri-template in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\ankit\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\ankit\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ankit\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\ankit\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ankit\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\ankit\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.2.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\ankit\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\ankit\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\ankit\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.16.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ankit\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ankit\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.2.3)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ankit\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\ankit\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.21)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ankit\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\ankit\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.2.3)
# Requirement already satisfied: executing in c:\users\ankit\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\ankit\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\ankit\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)

# %%
test_vec = embeddings.embed_query("hello world")
len(test_vec), test_vec[:5]
# Out:
# (768,
#  [0.02624971978366375,
#   0.013395597226917744,
#   -0.004533165134489536,
#   -0.021791458129882812,
#   0.05455183982849121])

# %% [markdown]
# ## Store chunks in a vector database (Chroma)

# %%
from langchain_chroma import Chroma
vector_store = Chroma(
          collection_name="scrum_guide",
          embedding_function=embeddings,
             persist_directory="./chroma_scrum_db"
)
ids=vector_store.add_documents(splits)
print("Stored chunks:",len(ids))
# Out:
# Stored chunks: 51

# %% [markdown]
# ## Retrieve relevant chunks (test retrieval)
# 1️⃣ Query was converted into an embedding vector
# 2️⃣ Every stored chunk already has an embedding vector
# 3️⃣ The vector store calculated cosine similarity
# 4️⃣ The top-3 closest chunks were returned
# The line prints the first 600 characters of the most relevant retrieved document chunk, allowing us to inspect and validate the retrieval output before passing it to the LLM

# %%
query = "What are the responsibilities of the Scrum Master?"
retrieved_docs = vector_store.similarity_search(query, k=3)

print("Retrieved:", len(retrieved_docs))
print("\n--- Top retrieved chunk ---\n")
print(retrieved_docs[0].page_content[:600])
# Out:
# Retrieved: 3
#
# --- Top retrieved chunk ---
#
# Scrum Masters are true leaders who serve the Scrum Team and the larger organization.
#
# The Scrum Master serves the Scrum Team in several ways, including:
#
# ● Coaching the team members in self-management and cross-functionality;
# ● Helping the Scrum Team focus on creating high-value Increments that meet the Definition of
# Done;
# ● Causing the removal of impediments to the Scrum Team’s progress; and,
# ● Ensuring that all Scrum events take place and are positive, productive, and kept within the
# timebox.
#
# The Scrum Master serves the Product Owner in several ways, including:

# %% [markdown]
# ## (Assignment requirement): Run at least two different queries
# This code connects retrieval + LLM so that:
#
# A user question is asked
#
# Relevant chunks are retrieved from the vector store
#
# Those chunks are passed to the LLM
#
# The LLM generates a grounded answer

# %%
# First, define the rag_answer function or import it from the appropriate module
def rag_answer(question, k=3):
    # Implement your RAG (Retrieval-Augmented Generation) logic here
    # This is a placeholder implementation
    return f"Answer to: {question} (using {k} documents)"

# Now use the function
questions = [
     "What are the responsibilities of Scrum Master ?",
     "What does the Scrum guide say about product owner role?"
]
for q in questions:
    ans = rag_answer(q, k=4)  # Now rag_answer is defined
    print("\nQ:", q)
    print("A:", ans)
# Out:
# Q: What are the responsibilities of Scrum Master ?
# A: Answer to: What are the responsibilities of Scrum Master ? (using 4 documents)
#
# Q: What does the Scrum guide say about product owner role?
# A: Answer to: What does the Scrum guide say about product owner role? (using 4 documents)

# %%
def rag_answer(question, k=3):
    if "Scrum Master" in question:
        return "The Scrum Master is responsible for coaching the team, removing impediments, and ensuring Scrum is understood."
    elif "Product Owner" in question:
        return "The Product Owner is accountable for maximizing product value and managing the Product Backlog."
    else:
        return "I don't know yet."

# %%
# !pip install -U langchain langchain-community langchain-openai
# Out:
# Requirement already satisfied: langchain in c:\users\ankit\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: langchain-community in c:\users\ankit\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-openai in c:\users\ankit\anaconda3\lib\site-packages (1.1.6)
# Collecting langchain-openai
#   Downloading langchain_openai-1.1.7-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in c:\users\ankit\anaconda3\lib\site-packages (from langchain) (1.2.6)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\ankit\anaconda3\lib\site-packages (from langchain) (1.0.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ankit\anaconda3\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.6.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (24.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (8.2.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ankit\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (2.1)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.1)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.27.0)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.2.0)
# Requirement already satisfied: certifi in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: idna in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.7)
# Requirement already satisfied: sniffio in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ankit\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\ankit\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ankit\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ankit\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ankit\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-openai) (2.11.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ankit\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\ankit\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: tqdm>4 in c:\users\ankit\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\ankit\anaconda3\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: colorama in c:\users\ankit\anaconda3\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)
# Downloading langchain_openai-1.1.7-py3-none-any.whl (84 kB)
# Installing collected packages: langchain-openai
#   Attempting uninstall: langchain-openai
#     Found existing installation: langchain-openai 1.1.6
#     Uninstalling langchain-openai-1.1.6:
#       Successfully uninstalled langchain-openai-1.1.6
# Successfully installed langchain-openai-1.1.7

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\ankit\anaconda3\python.exe

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 1.2.4
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\ankit\anaconda3\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:

# %%
# !pip uninstall langchain -y
# !pip uninstall langchain-community -y
# !pip uninstall langchain-openai -y

# !pip install --no-cache-dir langchain langchain-community langchain-openai
# Out:
# Found existing installation: langchain 1.2.4
# Uninstalling langchain-1.2.4:
#   Successfully uninstalled langchain-1.2.4
# Found existing installation: langchain-community 0.4.1
# Uninstalling langchain-community-0.4.1:
#   Successfully uninstalled langchain-community-0.4.1
# Found existing installation: langchain-openai 1.1.7
# Uninstalling langchain-openai-1.1.7:
#   Successfully uninstalled langchain-openai-1.1.7
# Collecting langchain
#   Downloading langchain-1.2.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-1.1.7-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in c:\users\ankit\anaconda3\lib\site-packages (from langchain) (1.2.6)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\ankit\anaconda3\lib\site-packages (from langchain) (1.0.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ankit\anaconda3\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.6.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (24.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (8.2.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ankit\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (2.1)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.1)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.27.0)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.2.0)
# Requirement already satisfied: certifi in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: idna in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.7)
# Requirement already satisfied: sniffio in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ankit\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\ankit\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ankit\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ankit\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ankit\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-openai) (2.11.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ankit\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\ankit\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: tqdm>4 in c:\users\ankit\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\ankit\anaconda3\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: colorama in c:\users\ankit\anaconda3\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)
# Downloading langchain-1.2.4-py3-none-any.whl (107 kB)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 18.2 MB/s  0:00:00
# Downloading langchain_openai-1.1.7-py3-none-any.whl (84 kB)
# Installing collected packages: langchain-openai, langchain-community, langchain
#
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    ---------------------------------------- 3/3 [langchain]
#
# Successfully installed langchain-1.2.4 langchain-community-0.4.1 langchain-openai-1.1.7

# %%
# !pip list | findstr langchain
# Out:
# langchain                                1.2.4
# langchain-chroma                         1.1.0
# langchain-classic                        1.0.1
# langchain-community                      0.4.1
# langchain-core                           1.2.6
# langchain-huggingface                    1.2.0
# langchain-ollama                         1.0.1
# langchain-openai                         1.1.7
# langchain-text-splitters                 1.1.0

# %%
# !pip list | findstr langchain
# Out:
# langchain                                1.2.4
# langchain-chroma                         1.1.0
# langchain-classic                        1.0.1
# langchain-community                      0.4.1
# langchain-core                           1.2.6
# langchain-huggingface                    1.2.0
# langchain-ollama                         1.0.1
# langchain-openai                         1.1.7
# langchain-text-splitters                 1.1.0

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\ankit\anaconda3\python.exe

# %%
import sys
# !{sys.executable} -m pip install -U langchain langchain-community langchain-openai
# Out:
# Requirement already satisfied: langchain in c:\users\ankit\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: langchain-community in c:\users\ankit\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-openai in c:\users\ankit\anaconda3\lib\site-packages (1.1.7)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in c:\users\ankit\anaconda3\lib\site-packages (from langchain) (1.2.6)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\ankit\anaconda3\lib\site-packages (from langchain) (1.0.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ankit\anaconda3\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.6.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (24.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (8.2.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ankit\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (2.1)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.1)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.27.0)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\ankit\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.2.0)
# Requirement already satisfied: certifi in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: idna in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.7)
# Requirement already satisfied: sniffio in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ankit\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ankit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\ankit\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ankit\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ankit\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ankit\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\ankit\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-openai) (2.11.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ankit\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\ankit\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: tqdm>4 in c:\users\ankit\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\ankit\anaconda3\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: colorama in c:\users\ankit\anaconda3\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)

# %%
# If you're on the newer LangChain packages
from langchain_openai import ChatOpenAI

# %%
import os
# Updated import path for ChatOpenAI in newer versions of LangChain
from langchain_openai import ChatOpenAI  # Changed from langchain.chat_models

# Method 1: Set the API key in your environment variables
os.environ["OPENAI_API_KEY"] = "your-api-key-here"  # Replace with your actual OpenAI API key

# Method 2: Or pass the API key directly to the ChatOpenAI constructor
llm = ChatOpenAI(
    model="gpt-3.5-turbo", 
    temperature=0,
    api_key="your-api-key-here"  # Replace with your actual OpenAI API key
)

# Choose either Method 1 or Method 2, not both

# %%
# First, define or import the rag_answer function
# For example, if it's a custom function you need to define:
def rag_answer(question, k=3):
    # This is a placeholder implementation
    # Replace with your actual RAG (Retrieval-Augmented Generation) implementation
    answer = f"This is a simulated answer to: {question}"
    context = ["context1", "context2", "context3", "context4"][:k]
    return answer, context

# Now use the function
questions = [
    "What are the responsibilities of the Scrum Master?",
    "What does the Scrum Guide say about the Product Owner role?"
]

for q in questions:
    ans, _ = rag_answer(q, k=4)
    print("\nQ:", q)
    print("A:", ans)
    print("-"*80)
# Out:
# Q: What are the responsibilities of the Scrum Master?
# A: This is a simulated answer to: What are the responsibilities of the Scrum Master?
# --------------------------------------------------------------------------------
#
# Q: What does the Scrum Guide say about the Product Owner role?
# A: This is a simulated answer to: What does the Scrum Guide say about the Product Owner role?
# --------------------------------------------------------------------------------

# %%
def rag_answer(question, k=4):
    # ensure retriever uses k docs
    retriever.search_kwargs["k"] = k
    
    result = rag_chain.invoke({"input": question})
    
    # Depending on langchain version, output key may differ
    answer = result.get("answer") or result.get("output_text") or str(result)
    context_docs = result.get("context", [])
    
    return answer, context_docs

# %%
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings

# %%
embeddings = OpenAIEmbeddings()

# %%
from pathlib import Path
from langchain_community.document_loaders import PyPDFLoader

# Fix the path by using raw string (r prefix) or double backslashes or forward slashes
# Option 1: Use raw string
PDF_PATH = r"C:\Users\ankit\OneDrive\Desktop\Data Science\GEN AI Tiger\2020-Scrum-Guide-US.pdf"

# Option 2: Use double backslashes
# PDF_PATH = "C:\\Users\\ankit\\OneDrive\\Desktop\\Data Science\\GEN AI Tiger\\2020-Scrum-Guide-US.pdf"

# Option 3: Use forward slashes (works on Windows too)
# PDF_PATH = "C:/Users/ankit/OneDrive/Desktop/Data Science/GEN AI Tiger/2020-Scrum-Guide-US.pdf"

# Option 4: Use pathlib (recommended)
# PDF_PATH = Path("C:/Users/ankit/OneDrive/Desktop/Data Science/GEN AI Tiger/2020-Scrum-Guide-US.pdf")

loader = PyPDFLoader(str(PDF_PATH))
documents = loader.load()

# %%
len(documents)
# Out:
# 14

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunks = text_splitter.split_documents(documents)

print(f"Total chunks created: {len(chunks)}")
print(chunks[0].page_content[:300])
# Out:
# Total chunks created: 42
# Ken Schwaber & Jeff Sutherland
#
#
#
#
#
#
#
#
#
#
# The Scrum Guide
#
# The Definitive Guide to Scrum: The Rules of the Game
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# November 2020

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-mpnet-base-v2"
)
print("Embeddings ready ✅")
# Out:
# Embeddings ready ✅

# %%
import sys
# !{sys.executable} -m pip install faiss-cpu
# Out:
# Requirement already satisfied: faiss-cpu in c:\users\ankit\anaconda3\lib\site-packages (1.13.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\ankit\anaconda3\lib\site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in c:\users\ankit\anaconda3\lib\site-packages (from faiss-cpu) (24.1)

# %%
from langchain_community.vectorstores import FAISS

vectordb = FAISS.from_documents(chunks, embeddings)
retriever = vectordb.as_retriever(search_kwargs={"k": 4})
print("FAISS vector DB ready ✅")
# Out:
# FAISS vector DB ready ✅

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

# %%
docs = retriever.invoke("What is a Scrum Master?")

print(len(docs))
print(docs[0].page_content[:300])
print(docs[0].metadata)
# Out:
# 4
# many stakeholders in the Product Backlog. Those wanting to change the Product Backlog can do so by
# trying to convince the Product Owner.
# Scrum Master
# The Scrum Master is accountable for establishing Scrum as defined in the Scrum Guide. They do this by
# helping everyone understand Scrum theory and
# {'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2020-11-09T13:11:26+00:00', 'moddate': '2020-11-09T13:11:26+00:00', 'source': 'C:\\Users\\ankit\\OneDrive\\Desktop\\Data Science\\GEN AI Tiger\\2020-Scrum-Guide-US.pdf', 'total_pages': 14, 'page': 6, 'page_label': '7'}

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template(
"""Answer ONLY using the context from the Scrum Guide.
If the answer is not in the context, say: "Not found in the provided document."

Question:
{question}

Context:
{context}

Answer:"""
)

# %%
def rag_answer(question, k=4):
    # retrieve top-k chunks
    docs = retriever.invoke(question)

    context = "\n\n".join(d.page_content for d in docs)

    # build prompt
    messages = prompt.format_messages(
        question=question,
        context=context
    )

    # call LLM
    response = llm.invoke(messages)

    return response.content, docs

# %%
import os
os.environ["OPENAI_API_KEY"] = "sk-REPLACE_WITH_REAL_KEY"

# %%
import os
os.environ["OPENAI_API_KEY"] = "sk-PASTE_YOUR_REAL_KEY_HERE"

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)

# %%
import os
print("Has OPENAI_API_KEY?", bool(os.getenv("OPENAI_API_KEY")))
print("Key prefix:", os.getenv("OPENAI_API_KEY")[:3])
# Out:
# Has OPENAI_API_KEY? True
# Key prefix: sk-

# %%
from langchain_community.chat_models import ChatOllama

llm = ChatOllama(model="llama3", temperature=0)

# %% [markdown]
# a) Query embedding
#
# Your question q is converted into an embedding vector
#
# b) Retrieval
#
# Top 4 most similar chunks are retrieved from the vector store
#
# These chunks come from the Scrum Guide PDF
#
# c) Context injection
#
# Retrieved chunks are stuffed into the prompt (chain_type="stuff")
#
# d) LLM generation
#
# Llama 3 generates an answer only using that context

# %% [markdown]
# 3️⃣ Why the SAME question can produce DIFFERENT answers
#
# This is an important RAG concept:
#
# In RAG, answers are a function of context, not just the question.
#
# Mathematically (conceptually):
#
# Answer = f(Question + Retrieved Context + Prompt + LLM)
#
#
# Earlier:
#
# Context was empty / fake / partial
#
# 7th time:
#
# Context = real Scrum Guide sections
#
# Prompt = instructive
#
# LLM = deterministic (temperature=0)
#
# ➡️ Hence: longer, better, grounded answers

# %%
for q in questions:
    ans, docs = rag_answer(q, k=4)
    print("\nQ:", q)
    print("A:", ans)
    print("Sources/pages:", [d.metadata.get("page") for d in docs])
    print("-"*80)
# Out:
# Q: What are the responsibilities of the Scrum Master?
# A: According to the provided context, the responsibilities of the Scrum Master are:
#
# * Helping the Scrum Team focus on creating high-value Increments that meet the Definition of Done;
# * Causing the removal of impediments to the Scrum Team’s progress; and,
# * Ensuring that all Scrum events take place and are positive, productive, and kept within the timebox.
#
# Additionally, the Scrum Master serves the Product Owner by helping them manage the Product Backlog.
# Sources/pages: [6, 6, 5, 7]
# --------------------------------------------------------------------------------
#
# Q: What does the Scrum Guide say about the Product Owner role?
# A: According to the Scrum Guide, the Product Owner is accountable for:
#
# * Developing and explicitly communicating the Product Goal
# * Creating and clearly communicating Product Backlog items
# * Ordering Product Backlog items
# * Ensuring that the Product Backlog is transparent, visible, and understood
# * Maximizing the value of the product resulting from the work of the Scrum Team
#
# The Product Owner may delegate some of these responsibilities to others, but remains accountable for their decisions.
# Sources/pages: [6, 5, 5, 6]
# --------------------------------------------------------------------------------

# %%
# !pip install chromadb
# Out:
# Requirement already satisfied: chromadb in c:\users\ankit\anaconda3\lib\site-packages (1.4.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (2.12.5)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\ankit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.40.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (3.11.5)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\ankit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\ankit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\ankit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\ankit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ankit\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ankit\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ankit\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ankit\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.10.5)
# Requirement already satisfied: packaging>=19.1 in c:\users\ankit\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Requirement already satisfied: pyproject_hooks in c:\users\ankit\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\ankit\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ankit\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.10.6)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\ankit\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.45.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\ankit\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\ankit\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\ankit\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ankit\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ankit\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\ankit\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Requirement already satisfied: coloredlogs in c:\users\ankit\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\ankit\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\ankit\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.2)
# Requirement already satisfied: sympy in c:\users\ankit\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\ankit\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\ankit\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\ankit\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in c:\users\ankit\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in c:\users\ankit\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\ankit\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ankit\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ankit\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\ankit\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.35.1)
# Requirement already satisfied: filelock in c:\users\ankit\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\ankit\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\ankit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\ankit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\ankit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\ankit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\ankit\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\ankit\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)

# %%
from langchain_community.vectorstores import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
from langchain_core.messages import HumanMessage

def rag_answer_with_vs(question: str, k: int = 3):
    docs_ret = vs_small.similarity_search(question, k=k)
    context = "\n\n".join(d.page_content for d in docs_ret)

    prompt_text = f"""Use ONLY the context below to answer.
If the answer is not in the context, say: "Not found in the provided document."

Context:
{context}

Question: {question}

Answer:"""

    response = llm.invoke([HumanMessage(content=prompt_text)])
    return response.content, docs_ret

# %% [markdown]
# ## Small Chunks

# %%
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_core.documents import Document

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# ✅ YOU MUST define this (replace with your real chunks list)
small_chunks = [
    "chunk 1 text ...",
    "chunk 2 text ...",
]

docs_small = [
    Document(page_content=ch, metadata={"source": "scrum_guide", "chunk_type": "small", "chunk_id": i})
    for i, ch in enumerate(small_chunks)
]

vs_small = FAISS.from_documents(docs_small, embeddings)
print("vs_small ready. Total docs:", len(docs_small))
# Out:
# vs_small ready. Total docs: 2

# %%
[x for x in globals().keys() if "chunk" in x.lower() or "split" in x.lower() or "doc" in x.lower()]
# Out:
# ['__doc__', 'Document', 'small_chunks', 'docs_small']

# %% [markdown]
# ## Large Chunks

# %%
pip install -U langchain-chroma chromadb
# Out:
# Requirement already satisfied: langchain-chroma in c:\users\ankit\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: chromadb in c:\users\ankit\anaconda3\lib\site-packages (1.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-chroma) (1.2.6)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-chroma) (1.26.4)
# Requirement already satisfied: build>=1.0.3 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (2.12.5)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\ankit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.40.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (3.11.5)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\ankit\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.6.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (24.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\ankit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ankit\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ankit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.23.0)
# Requirement already satisfied: anyio in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: certifi in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: sniffio in c:\users\ankit\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ankit\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.5 in c:\users\ankit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\ankit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\ankit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ankit\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ankit\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ankit\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.2.3)
# Requirement already satisfied: pyproject_hooks in c:\users\ankit\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\ankit\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ankit\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.10.6)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\ankit\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.45.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\ankit\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\ankit\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\ankit\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ankit\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ankit\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\ankit\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Requirement already satisfied: coloredlogs in c:\users\ankit\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\ankit\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\ankit\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.2)
# Requirement already satisfied: sympy in c:\users\ankit\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\ankit\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\ankit\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\ankit\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in c:\users\ankit\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in c:\users\ankit\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\ankit\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ankit\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ankit\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ankit\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\ankit\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.35.1)
# Requirement already satisfied: filelock in c:\users\ankit\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ankit\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\ankit\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\ankit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\ankit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\ankit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\ankit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\ankit\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\ankit\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ankit\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_chroma import Chroma

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma

splitter_large = RecursiveCharacterTextSplitter(chunk_size=1500, chunk_overlap=200)
splits_large = splitter_large.split_documents(docs)

vs_large = Chroma(
    collection_name="scrum_large",
    embedding_function=embeddings,
    persist_directory="./chroma_scrum_large"
)

vs_large.add_documents(splits_large)
print("Large chunks stored:", len(splits_large))
# Out:
# Large chunks stored: 28
